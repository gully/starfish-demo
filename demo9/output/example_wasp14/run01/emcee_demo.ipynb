# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
ws = np.load("emcee_chain.npy")

# %%
ws.shape
# Out:
# (36, 2, 12)

# %%
plt.plot(ws[0, :, 0])

# %%
import seaborn as sns

# %%
plt.hist(ws[:, :, 0])
# Out:
# ([array([ 1.,  1.,  0.,  2.,  2.,  7.,  6.,  8.,  2.,  7.]),
#   array([ 1.,  1.,  0.,  3.,  4.,  4.,  7.,  6.,  6.,  4.])],
#  array([ 6212.57714849,  6214.77062573,  6216.96410298,  6219.15758023,
#          6221.35105747,  6223.54453472,  6225.73801196,  6227.93148921,
#          6230.12496645,  6232.3184437 ,  6234.51192095]),
#  <a list of 2 Lists of Patches objects>)
